# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from keras.optimizers import Adam
import tensorflow.keras.backend as K
from keras.callbacks import ModelCheckpoint
from keras.callbacks import ReduceLROnPlateau
from keras.callbacks import EarlyStopping
from keras.callbacks import CSVLogger
from livelossplot import PlotLossesKeras

tf.config.run_functions_eagerly(True)

# %%
DATASET = "traces_out/malware_web_mixed_cleaned.csv"
MODEL_CHECKPOINT_PATH = "models/malware_web_mixed_cleaned.keras"
CSV_LOGGER_PATH = "logs/malware_web_mixed_cleaned.csv"
MIN_LR = 1e-6
START_LR = 1e-3
BATCH_SIZE=64
EPOCHS=200

# %%
X = pd.read_csv(DATASET, header=None)
Y = X.iloc[:, -2:]
X = X.iloc[:, :-2]
print(f"shape of X: {X.shape}")
print(f"shape of Y: {Y.shape}")
# Out:
# shape of X: (351977, 43)
# shape of Y: (351977, 2)

# %%
#
# Build Model (Simple LSTM)
#

model = tf.keras.Sequential([
    layers.Input(shape=(43,), batch_size=1),
    layers.Embedding(256, 32),
    layers.LSTM(16),
    layers.Dense(2, activation='sigmoid')])

model.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(learning_rate=START_LR),
    metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ (1, 43, 32)            │         8,192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (1, 16)                │         3,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (1, 2)                 │            34 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,362 (44.38 KB)
#  Trainable params: 11,362 (44.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# plot callback
plot_losses = PlotLossesKeras()
# save model to file at each epoch callback
checkpoint = ModelCheckpoint(filepath=MODEL_CHECKPOINT_PATH, 
                            monitor='val_loss',
                            verbose=1, 
                            save_best_only=True,
                            mode='min')
# learning rate adjustment callback
reduce_lr = ReduceLROnPlateau(monitor='val_loss', min_lr=MIN_LR)
# early stopping callback
early_stop = EarlyStopping(patience=20)
# csv callback
csv_logger = CSVLogger(CSV_LOGGER_PATH)

# %%
model.fit(X, Y,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    callbacks=[checkpoint, reduce_lr, early_stop, csv_logger, plot_losses],
    verbose=1)
# Out:
# Epoch 1/200
# /home/ubuntu/workspace/virussign-traces/.venv/lib/python3.10/site-packages/tensorflow/python/data/ops/structured_function.py:258: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
#  359/5500 ━━━━━━━━━━━━━━━━━━━━ 21:59 257ms/step - accuracy: 0.6585 - loss: 0.6420
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_429161/2837220182.py in ?()
# ----> 1 model.fit(X, Y,
#       2     batch_size=BATCH_SIZE,
#       3     epochs=EPOCHS,
#       4     callbacks=[checkpoint, reduce_lr, early_stop, csv_logger, plot_losses],
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py in ?(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     316             callbacks.on_epoch_begin(epoch)
#     317             with epoch_iterator.catch_stop_iteration():
#     318                 for step, iterator in epoch_iterator.enumerate_epoch():
#     319                     callbacks.on_train_batch_begin(step)
# --> 320                     logs = self.train_function(iterator)
#     321                     callbacks.on_train_batch_end(step, logs)
#     322                     if self.stop_training:
#     323                         break
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in ?(self, *args, **kwds)
#     806   def __call__(self, *args, **kwds):
#     807     # Implements PolymorphicFunction.__call__.
#     808     if self._run_functions_eagerly:
#     809       with trace.Trace(self._name, tf_function_call="eager"):
# --> 810         return self._python_function(*args, **kwds)
#     811
#     812     # Only count the statistics the first time, before initialization took
#     813     # place.
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py in ?(*args, **kwargs)
#     641   def wrapper(*args, **kwargs):
#     642     with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643       return func(*args, **kwargs)
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py in ?(iterator)
#     117         @tf.autograph.experimental.do_not_convert
#     118         def one_step_on_iterator(iterator):
#     119             """Runs a single training step given a Dataset iterator."""
#     120             data = next(iterator)
# --> 121             outputs = self.distribute_strategy.run(
#     122                 one_step_on_data, args=(data,)
#     123             )
#     124             outputs = reduce_per_replica(
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/tensorflow/python/distribute/distribute_lib.py in ?(***failed resolving arguments***)
#    1669       # tf.distribute supports Eager functions, so AutoGraph should not be
#    1670       # applied when the caller is also in Eager mode.
#    1671       fn = autograph.tf_convert(
#    1672           fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1673       return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/tensorflow/python/distribute/distribute_lib.py in ?(self, fn, args, kwargs)
#    3259     _require_cross_replica_or_default_context_extended(self)
#    3260     if kwargs is None:
#    3261       kwargs = {}
#    3262     with self._container_strategy().scope():
# -> 3263       return self._call_for_each_replica(fn, args, kwargs)
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/tensorflow/python/distribute/distribute_lib.py in ?(self, fn, args, kwargs)
#    4059   def _call_for_each_replica(self, fn, args, kwargs):
#    4060     with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 4061       return fn(*args, **kwargs)
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in ?(self, *args, **kwds)
#     806   def __call__(self, *args, **kwds):
#     807     # Implements PolymorphicFunction.__call__.
#     808     if self._run_functions_eagerly:
#     809       with trace.Trace(self._name, tf_function_call="eager"):
# --> 810         return self._python_function(*args, **kwds)
#     811
#     812     # Only count the statistics the first time, before initialization took
#     813     # place.
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/tensorflow/python/autograph/impl/api.py in ?(*args, **kwargs)
#     641   def wrapper(*args, **kwargs):
#     642     with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643       return func(*args, **kwargs)
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py in ?(data)
#     105         @tf.autograph.experimental.do_not_convert
#     106         def one_step_on_data(data):
#     107             """Runs a single training step on a batch of data."""
# --> 108             return self.train_step(data)
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py in ?(self, data)
#      47
#      48         # Forward pass
#      49         with tf.GradientTape() as tape:
#      50             if self._call_has_training_arg:
# ---> 51                 y_pred = self(x, training=True)
#      52             else:
#      53                 y_pred = self(x)
#      54             loss = self._compute_loss(
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/keras/src/layers/layer.py in ?(self, *args, **kwargs)
#     937                     "layers will not see the mask."
#     938                 )
#     939         finally:
#     940             # Destroy call context if we created it
# --> 941             self._maybe_reset_call_context()
#     942         return outputs
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/keras/src/ops/operation.py in ?(self, *args, **kwargs)
#      42             call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43                 call_fn,
#      44                 object_name=(f"{self.__class__.__name__}.call()"),
#      45             )
# ---> 46             return call_fn(*args, **kwargs)
#      47
#      48         # Plain flow.
#      49         if any_symbolic_tensors(args, kwargs):
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#     213                 new_e = e
#     214             raise new_e.with_traceback(e.__traceback__) from None
#     215         finally:
#     216             del signature
# --> 217             del bound_signature
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/keras/src/models/sequential.py in ?(self, inputs, training, mask)
#     211     def call(self, inputs, training=None, mask=None):
#     212         if self._functional:
# --> 213             return self._functional.call(inputs, training=training, mask=mask)
#     214
#     215         # Fallback: Just apply the layer sequence.
#     216         # This typically happens if `inputs` is a nested struct.
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/keras/src/models/functional.py in ?(self, inputs, training, mask)
#     178             masks = tree.flatten(mask)
#     179             for x, mask in zip(inputs, masks):
#     180                 if mask is not None:
#     181                     backend.set_keras_mask(x, mask)
# --> 182         outputs = self._run_through_graph(
#     183             inputs, operation_fn=lambda op: operation_fn(op, training=training)
#     184         )
#     185         return unpack_singleton(outputs)
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/keras/src/ops/function.py in ?(self, inputs, operation_fn, call_fn)
#     167                 op = operation_fn(node.operation)
#     168                 if call_fn is not None:
#     169                     outputs = call_fn(op, *args, **kwargs)
#     170                 else:
# --> 171                     outputs = op(*args, **kwargs)
#     172
#     173                 # Update tensor_dict.
#     174                 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/keras/src/models/functional.py in ?(*args, **kwargs)
#     580             and operation._call_has_training_arg
#     581             and training is not None
#     582         ):
#     583             kwargs["training"] = training
# --> 584         return operation(*args, **kwargs)
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/keras/src/layers/layer.py in ?(self, *args, **kwargs)
#     937                     "layers will not see the mask."
#     938                 )
#     939         finally:
#     940             # Destroy call context if we created it
# --> 941             self._maybe_reset_call_context()
#     942         return outputs
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/keras/src/ops/operation.py in ?(self, *args, **kwargs)
#      42             call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43                 call_fn,
#      44                 object_name=(f"{self.__class__.__name__}.call()"),
#      45             )
# ---> 46             return call_fn(*args, **kwargs)
#      47
#      48         # Plain flow.
#      49         if any_symbolic_tensors(args, kwargs):
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#     213                 new_e = e
#     214             raise new_e.with_traceback(e.__traceback__) from None
#     215         finally:
#     216             del signature
# --> 217             del bound_signature
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/lstm.py in ?(self, sequences, initial_state, mask, training)
#     569     def call(self, sequences, initial_state=None, mask=None, training=False):
# --> 570         return super().call(
#     571             sequences, mask=mask, training=training, initial_state=initial_state
#     572         )
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py in ?(self, sequences, initial_state, mask, training)
#     402         self._maybe_config_dropout_masks(
#     403             self.cell, sequences[:, 0, :], initial_state
#     404         )
#     405
# --> 406         last_output, outputs, states = self.inner_loop(
#     407             sequences=sequences,
#     408             initial_state=initial_state,
#     409             mask=mask,
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/lstm.py in ?(self, sequences, initial_state, mask, training)
#     561                 "but cuDNN is not supported for this layer configuration "
#     562                 "with this backend. Pass use_cudnn='auto' to fallback "
#     563                 "to a non-cuDNN implementation."
#     564             )
# --> 565         return super().inner_loop(
#     566             sequences, initial_state, mask=mask, training=training
#     567         )
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py in ?(self, sequences, initial_state, mask, training)
#     342
#     343         if not tree.is_nested(initial_state):
#     344             initial_state = [initial_state]
#     345
# --> 346         return backend.rnn(
#     347             step,
#     348             sequences,
#     349             initial_state,
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/keras/src/backend/tensorflow/rnn.py in ?(step_function, inputs, initial_states, go_backwards, mask, constants, unroll, input_length, time_major, zero_output_for_mask, return_all_outputs)
#     424                     initial_states, flat_new_state
#     425                 )
#     426                 return (time + 1, output_ta_t) + tuple(new_states)
#     427
# --> 428             final_outputs = tf.while_loop(
#     429                 body=_step,
#     430                 loop_vars=(time, output_ta) + states,
#     431                 **while_loop_kwargs,
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/tensorflow/python/util/deprecation.py in ?(*args, **kwargs)
#     656                   _call_location(), decorator_utils.get_qualified_name(func),
#     657                   func.__module__, arg_name, arg_value,
#     658                   'in a future version' if date is None else
#     659                   ('after %s' % date), instructions)
# --> 660       return func(*args, **kwargs)
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/tensorflow/python/ops/while_loop.py in ?(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, maximum_iterations, name)
#     237   ...   print(sess.run(x_out).shape)
#     238   (1000, 100)
#     239
#     240   """
# --> 241   return while_loop(
#     242       cond=cond,
#     243       body=body,
#     244       loop_vars=loop_vars,
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/tensorflow/python/ops/while_loop.py in ?(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#     484
#     485       loop_var_structure = nest.map_structure(type_spec.type_spec_from_value,
#     486                                               list(loop_vars))
#     487       while cond(*loop_vars):
# --> 488         loop_vars = body(*loop_vars)
#     489         if try_to_pack and not isinstance(loop_vars, (list, tuple)):
#     490           packed = True
#     491           loop_vars = (loop_vars,)
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/tensorflow/python/ops/while_loop.py in ?(i, lv)
# --> 479         body = lambda i, lv: (i + 1, orig_body(*lv))
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/keras/src/backend/tensorflow/rnn.py in ?(time, output_ta_t, *states)
#     407                     Tuple: `(time + 1,output_ta_t) + tuple(new_states)`
#     408                 """
#     409                 current_input = tuple(ta.read(time) for ta in input_ta)
#     410                 current_input = tree.pack_sequence_as(inputs, current_input)
# --> 411                 output, new_states = step_function(
#     412                     current_input, tuple(states) + tuple(constants)
#     413                 )
#     414                 flat_new_state = tree.flatten(new_states)
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py in ?(inputs, states)
#     337         def step(inputs, states):
# --> 338             output, new_states = self.cell(inputs, states, **cell_kwargs)
#     339             if not tree.is_nested(new_states):
#     340                 new_states = [new_states]
#     341             return output, new_states
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/keras/src/layers/layer.py in ?(self, *args, **kwargs)
#     937                     "layers will not see the mask."
#     938                 )
#     939         finally:
#     940             # Destroy call context if we created it
# --> 941             self._maybe_reset_call_context()
#     942         return outputs
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/keras/src/ops/operation.py in ?(self, *args, **kwargs)
#      42             call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43                 call_fn,
#      44                 object_name=(f"{self.__class__.__name__}.call()"),
#      45             )
# ---> 46             return call_fn(*args, **kwargs)
#      47
#      48         # Plain flow.
#      49         if any_symbolic_tensors(args, kwargs):
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py in ?(*args, **kwargs)
#     213                 new_e = e
#     214             raise new_e.with_traceback(e.__traceback__) from None
#     215         finally:
#     216             del signature
# --> 217             del bound_signature
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/lstm.py in ?(self, inputs, states, training)
#     267             if self.use_bias:
#     268                 z += self.bias
#     269
#     270             z = ops.split(z, 4, axis=1)
# --> 271             c, o = self._compute_carry_and_output_fused(z, c_tm1)
#     272
#     273         h = o * self.activation(c)
#     274         return h, [h, c]
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/keras/src/layers/rnn/lstm.py in ?(self, z, c_tm1)
#     219         """Computes carry and output using fused kernels."""
#     220         z0, z1, z2, z3 = z
#     221         i = self.recurrent_activation(z0)
#     222         f = self.recurrent_activation(z1)
# --> 223         c = f * c_tm1 + i * self.activation(z2)
#     224         o = self.recurrent_activation(z3)
#     225         return c, o
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/tensorflow/python/framework/override_binary_operator.py in ?(x, y)
#     110         # TODO(b/178860388): Figure out why binary_op_wrapper and
#     111         #   r_binary_op_wrapper use different force_same_dtype values.
#     112         x, y = maybe_promote_tensors(x, y)
#     113         return func(x, y, name=name)
# --> 114       except (TypeError, ValueError) as e:
#     115         # Even if dispatching the op failed, the RHS may be a tensor aware
#     116         # object that can implement the operator with knowledge of itself
#     117         # and the tensor.
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/tensorflow/python/ops/tensor_math_operator_overrides.py in ?(x, y, name)
#      61 def _mul_dispatch_factory(x, y, name=None):
#      62   from tensorflow.python.ops import math_ops
#      63
# ---> 64   return math_ops._mul_dispatch(x, y, name=name)  # pylint: disable=protected-access
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/tensorflow/python/ops/math_ops.py in ?(x, y, name)
#    1707     new_vals = gen_sparse_ops.sparse_dense_cwise_mul(y.indices, y.values,
#    1708                                                      y.dense_shape, x, name)
#    1709     return sparse_tensor.SparseTensor(y.indices, new_vals, y.dense_shape)
#    1710   else:
# -> 1711     return multiply(x, y, name=name)
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/tensorflow/python/ops/weak_tensor_ops.py in ?(*args, **kwargs)
#     140   def wrapper(*args, **kwargs):
#     141     if not ops.is_auto_dtype_conversion_enabled():
# --> 142       return op(*args, **kwargs)
#     143     bound_arguments = signature.bind(*args, **kwargs)
#     144     bound_arguments.apply_defaults()
#     145     bound_kwargs = bound_arguments.arguments
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py in ?(*args, **kwargs)
#    1257
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
#    1260         return dispatch_target(*args, **kwargs)
# -> 1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263         # TypeError, when given unexpected types.  So we need to catch both.
#    1264         result = dispatch(op_dispatch_handler, args, kwargs)
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/tensorflow/python/ops/math_ops.py in ?(x, y, name)
#     522
#     523    * InvalidArgumentError: When `x` and `y` have incompatible shapes or types.
#     524   """
#     525
# --> 526   return gen_math_ops.mul(x, y, name)
#
# ~/workspace/virussign-traces/.venv/lib/python3.10/site-packages/tensorflow/python/ops/gen_math_ops.py in ?(x, y, name)
#    6825         _ctx, "Mul", name, x, y)
#    6826       return _result
#    6827     except _core._NotOkStatusException as e:
#    6828       _ops.raise_from_not_ok_status(e, name)
# -> 6829     except _core._FallbackException:
#    6830       pass
#    6831     try:
#    6832       return mul_eager_fallback(
#
# KeyboardInterrupt:
